# %% [markdown]
# # **Python Code for Performing Spectral Embedding using a Support Vector Machine**

# %% [markdown]
# ## **This code is provided by the 2024 CCBER Data Science Capstone group.**

# %%
# Load in necessary packages
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.manifold import SpectralEmbedding
from sklearn.cluster import KMeans

# %% [markdown]
# First, let's see how this method works using the digits dataset from sklearn library. The code below was provided by Dr. Laura Baracaldo Lancheros.

# %%
######## Load a dataset of images (I'm using the digits dataset from sklearn library)
digits = load_digits()
data = digits.data
images = digits.images
##### Perform Spectral Embedding (a method related to diffusion maps) to reduce dimensionality
embedding = SpectralEmbedding(n_components=2, affinity='nearest_neighbors')
dmap = embedding.fit_transform(data)
##### Perform k-means clustering on the reduced-dimensional space
kmeans = KMeans(n_clusters=10, random_state=0).fit(dmap)
labels = kmeans.labels_
# Visualize the clustering results
plt.figure(figsize=(12, 6))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(images[labels == i][0], cmap=plt.cm.gray_r, interpolation='nearest')
    plt.title('Cluster {}'.format(i))
    plt.xticks(())
    plt.yticks(())
plt.suptitle('Clustering of Images using Spectral Embedding', fontsize=16)
plt.show()

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import matplotlib.pyplot as plt

# Load a dataset of labeled images
digits = load_digits()
data = digits.data
target = digits.target
images = digits.images

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=42)

# Train a classifier (for example, Support Vector Machine)
classifier = SVC(kernel='linear', C=1.0, random_state=42)
classifier.fit(X_train, y_train)

# Evaluate the classifier
accuracy = classifier.score(X_test, y_test)
print("Accuracy:", accuracy)

# Visualize some predictions
plt.figure(figsize=(12, 6))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(images[i], cmap=plt.cm.gray_r, interpolation='nearest')
    predicted_label = classifier.predict([data[i]])[0]
    plt.title('Predicted: {}'.format(predicted_label))
    plt.xticks(())
    plt.yticks(())
plt.suptitle('Classification of Images using SVM', fontsize=16)
plt.show()
# Out:
# Accuracy: 0.9777777777777777

# %% [markdown]
# Now, let's try to apply this to our more complex images. I am importing the 'tqdm' package so when the code runs, we see visually that it is looping through each image file in the folders. Furthermore, I am only training and testing this model on 16 of the provided species.

# %%
import os
import random
from PIL import Image
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.manifold import SpectralEmbedding
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Define a fixed size for resizing the images
image_size = (100, 100)  # Adjust as needed

# Initialize empty lists to store the resized image arrays and corresponding species identifiers
image_arrays = []
species_identifiers = []

# Define the path to the main folder
main_folder = "C:/Users/jenni/Downloads/BEEWINGCROPPED"


if not os.path.exists(main_folder):
    print(f"The path {main_folder} does not exist.")
else:
    # loop through each folder in the main folder
    for species_folder in tqdm(os.listdir(main_folder), desc="Processing folders"):
        species_folder_path = os.path.join(main_folder, species_folder)
        if os.path.isdir(species_folder_path):
            for image_file in tqdm(os.listdir(species_folder_path), desc=f"Processing {species_folder}", leave=False):
                # Skip files starting with '.'
                if not image_file.startswith('.'):
                    image_path = os.path.join(species_folder_path, image_file)
                    try:
                        with Image.open(image_path) as img:
                            # Ensure the image is in RGB mode
                            img = img.convert('RGB')
                            # Resize the image
                            img = img.resize(image_size, Image.BILINEAR)
                            # Convert to numpy array
                            image_array = np.array(img)
                            # Append the image array and species identifier to the lists
                            image_arrays.append(image_array)
                            species_identifiers.append(species_folder)
                    except Exception as e:
                        print(f"Error processing {image_path}: {e}")

    # ensure/resize all images so that they are the same shape before flattening

    image_arrays = [img for img in image_arrays if img.shape == (image_size[0], image_size[1], 3)]
    species_identifiers = [species_identifiers[i] for i in range(len(species_identifiers)) if image_arrays[i].shape == (image_size[0], image_size[1], 3)]
    
    if len(image_arrays) != len(species_identifiers):
        raise ValueError("Mismatch between number of valid images and species identifiers")

    # Create a DataFrame from the lists
    df = pd.DataFrame({'image_array': image_arrays, 'species_identifier': species_identifiers})

    # Flatten the image arrays
    # This transformation is necessary because most machine learning algorithms, including SVMs, operate on flat feature vectors rather than structured data like images. 
    # Flattening effectively "unrolls" the image pixels into a single vector, where each element represents the intensity value of a pixel.
    X = np.array([arr.flatten() for arr in df['image_array']])
    y = df['species_identifier']

    # Perform spectral embedding to extract features
    spectral_embedding = SpectralEmbedding(n_components=8, n_neighbors=10, random_state=42)
    X_embedding = spectral_embedding.fit_transform(X)

    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X_embedding, y, test_size=0.2, random_state=42)

    # Train a classifier (for example, Support Vector Machine)
    classifier = SVC(kernel='rbf', C=4.0, random_state=42, probability=True)
    classifier.fit(X_train, y_train)

    # Evaluate the classifier
    accuracy = classifier.score(X_test, y_test)
    print("Accuracy:", accuracy)

    # Visualize some random predictions
    plt.figure(figsize=(12, 6))
    random_indices = random.sample(range(len(X_test)), 10)
    for i, idx in enumerate(random_indices):
        plt.subplot(2, 5, i + 1)
        plt.imshow(df['image_array'].iloc[idx], interpolation='nearest')  # Use original color image
        predicted_probabilities = classifier.predict_proba([X_test[idx]])[0]
        top_three_indices = np.argsort(predicted_probabilities)[::-1][:3]
        top_three_species = [classifier.classes_[index] for index in top_three_indices]
        top_three_probs = [predicted_probabilities[index] for index in top_three_indices]
        plt.title('1st: {} ({:.2f}%)\n2nd: {} ({:.2f}%)\n3rd: {} ({:.2f}%)'.format(
            top_three_species[0], top_three_probs[0] * 100,
            top_three_species[1], top_three_probs[1] * 100,
            top_three_species[2], top_three_probs[2] * 100), fontsize=6)  # Set smaller font size for titles
        plt.xticks(())
        plt.yticks(())
    plt.suptitle('Classification of Images using SVM', fontsize=16)
    plt.show()
# Out:
# Processing folders:   0%|                                      | 0/16 [00:00<?, ?it/s]
# Processing Agapostemon Texanus:   0%|                           | 0/5 [00:00<?, ?it/s]
#
# Processing Andreda Candida-Isolated:   0%|                      | 0/7 [00:00<?, ?it/s]
# Processing Andreda Candida-Isolated:  57%|████████      | 4/7 [00:00<00:00, 35.17it/s]
# Processing folders:  12%|███▊                          | 2/16 [00:00<00:02,  6.53it/s]
# Processing Anthophora californica-isolated:   0%|               | 0/3 [00:00<?, ?it/s]
# Processing folders:  19%|█████▋                        | 3/16 [00:00<00:01,  7.56it/s]
# Processing Bombus sonorus isolated:   0%|                      | 0/12 [00:00<?, ?it/s]
# Processing Bombus sonorus isolated:   8%|█▏            | 1/12 [00:00<00:02,  5.17it/s]
# Processing Bombus sonorus isolated:  17%|██▎           | 2/12 [00:00<00:05,  1.93it/s]
# Processing Bombus sonorus isolated:  25%|███▌          | 3/12 [00:01<00:03,  2.28it/s]
# Processing Bombus sonorus isolated:  33%|████▋         | 4/12 [00:01<00:02,  2.87it/s]
# Processing Bombus sonorus isolated:  42%|█████▊        | 5/12 [00:01<00:02,  3.42it/s]
# Processing Bombus sonorus isolated:  50%|███████       | 6/12 [00:02<00:01,  3.13it/s]
# Processing Bombus sonorus isolated:  58%|████████▏     | 7/12 [00:02<00:01,  3.61it/s]
# Processing Bombus sonorus isolated:  67%|█████████▎    | 8/12 [00:02<00:01,  3.69it/s]
# Processing Bombus sonorus isolated:  75%|██████████▌   | 9/12 [00:02<00:00,  4.13it/s]
# Processing Bombus sonorus isolated:  83%|██████████▊  | 10/12 [00:02<00:00,  4.53it/s]
# Processing Bombus sonorus isolated:  92%|███████████▉ | 11/12 [00:03<00:00,  4.59it/s]
# Processing Bombus sonorus isolated: 100%|█████████████| 12/12 [00:03<00:00,  4.35it/s]
# Processing folders:  25%|███████▌                      | 4/16 [00:03<00:15,  1.33s/it]
# Processing Bombus-Californicus-Isolated:   0%|                 | 0/10 [00:00<?, ?it/s]
# Processing Bombus-Californicus-Isolated:  10%|▉        | 1/10 [00:00<00:02,  3.33it/s]
# Processing Bombus-Californicus-Isolated:  20%|█▊       | 2/10 [00:00<00:01,  4.13it/s]
# Processing Bombus-Californicus-Isolated:  30%|██▋      | 3/10 [00:00<00:01,  4.26it/s]
# Processing Bombus-Californicus-Isolated:  40%|███▌     | 4/10 [00:01<00:01,  3.74it/s]
# Processing Bombus-Californicus-Isolated:  50%|████▌    | 5/10 [00:01<00:01,  4.16it/s]
# Processing Bombus-Californicus-Isolated:  60%|█████▍   | 6/10 [00:01<00:00,  4.65it/s]
# Processing Bombus-Californicus-Isolated:  70%|██████▎  | 7/10 [00:01<00:00,  4.48it/s]
# Processing Bombus-Californicus-Isolated:  80%|███████▏ | 8/10 [00:01<00:00,  4.70it/s]
# Processing Bombus-Californicus-Isolated:  90%|████████ | 9/10 [00:02<00:00,  4.36it/s]
# Processing Bombus-Californicus-Isolated: 100%|████████| 10/10 [00:02<00:00,  4.91it/s]
# Processing folders:  31%|█████████▍                    | 5/16 [00:05<00:18,  1.65s/it]
# Processing Bombus-Melangypus-Isolated:   0%|                    | 0/5 [00:00<?, ?it/s]
# Processing Bombus-Melangypus-Isolated:  40%|████▊       | 2/5 [00:00<00:00, 16.35it/s]
# Processing Bombus-Melangypus-Isolated:  80%|█████████▌  | 4/5 [00:00<00:00, 10.64it/s]
# Processing folders:  38%|███████████▎                  | 6/16 [00:06<00:12,  1.25s/it]
# Processing Bombus-Vagans-isolated:   0%|                        | 0/7 [00:00<?, ?it/s]
# Processing Bombus-Vagans-isolated:  29%|████▌           | 2/7 [00:00<00:00, 17.02it/s]
# Processing Bombus-Vagans-isolated:  57%|█████████▏      | 4/7 [00:00<00:00,  7.64it/s]
# Processing Bombus-Vagans-isolated:  86%|█████████████▋  | 6/7 [00:00<00:00,  7.04it/s]
# Processing Bombus-Vagans-isolated: 100%|████████████████| 7/7 [00:00<00:00,  6.40it/s]
# Processing folders:  44%|█████████████▏                | 7/16 [00:07<00:10,  1.17s/it]
# Processing Diadasia bituberculata-isolated:   0%|              | 0/18 [00:00<?, ?it/s]
# Processing Diadasia bituberculata-isolated:  11%|▋     | 2/18 [00:00<00:00, 17.52it/s]
# Processing Diadasia bituberculata-isolated:  22%|█▎    | 4/18 [00:00<00:00, 17.31it/s]
# Processing Diadasia bituberculata-isolated:  33%|██    | 6/18 [00:00<00:00, 16.88it/s]
# Processing Diadasia bituberculata-isolated:  44%|██▋   | 8/18 [00:00<00:00, 16.72it/s]
# Processing Diadasia bituberculata-isolated:  56%|██▊  | 10/18 [00:00<00:00, 13.17it/s]
# Processing Diadasia bituberculata-isolated:  67%|███▎ | 12/18 [00:00<00:00, 14.20it/s]
# Processing Diadasia bituberculata-isolated:  78%|███▉ | 14/18 [00:00<00:00, 14.74it/s]
# Processing Diadasia bituberculata-isolated:  89%|████▍| 16/18 [00:01<00:00, 14.44it/s]
# Processing Diadasia bituberculata-isolated: 100%|█████| 18/18 [00:01<00:00, 13.10it/s]
# Processing folders:  50%|███████████████               | 8/16 [00:08<00:09,  1.20s/it]
# Processing Diadasia-australis-isolated:   0%|                   | 0/2 [00:00<?, ?it/s]
# Processing Diadasia-australis-isolated:  50%|█████▌     | 1/2 [00:00<00:00,  9.60it/s]
# Processing Diadasia-australis-isolated: 100%|███████████| 2/2 [00:00<00:00,  9.46it/s]
# Processing folders:  56%|████████████████▉             | 9/16 [00:08<00:06,  1.12it/s]
# Processing Diadasia-enavata-isolated:   0%|                     | 0/3 [00:00<?, ?it/s]
# Processing Diadasia-enavata-isolated: 100%|█████████████| 3/3 [00:00<00:00, 14.58it/s]
# Processing folders:  62%|██████████████████▏          | 10/16 [00:09<00:04,  1.46it/s]
# Processing Eucera frater albopilosa-isolated:   0%|             | 0/4 [00:00<?, ?it/s]
# Processing Eucera frater albopilosa-isolated:  25%|█▎   | 1/4 [00:00<00:00,  7.62it/s]
# Processing Eucera frater albopilosa-isolated:  50%|██▌  | 2/4 [00:00<00:00,  8.20it/s]
# Processing Eucera frater albopilosa-isolated:  75%|███▊ | 3/4 [00:00<00:00,  8.74it/s]
# Processing Eucera frater albopilosa-isolated: 100%|█████| 4/4 [00:00<00:00,  7.47it/s]
# Processing folders:  69%|███████████████████▉         | 11/16 [00:09<00:03,  1.58it/s]
# Processing Habropoda- tristissima-Isolated:   0%|               | 0/5 [00:00<?, ?it/s]
# Processing Habropoda- tristissima-Isolated:  20%|█▍     | 1/5 [00:00<00:00,  7.27it/s]
# Processing Habropoda- tristissima-Isolated:  40%|██▊    | 2/5 [00:00<00:00,  4.41it/s]
# Processing Habropoda- tristissima-Isolated:  60%|████▏  | 3/5 [00:01<00:01,  1.72it/s]
# Processing Habropoda- tristissima-Isolated:  80%|█████▌ | 4/5 [00:01<00:00,  2.47it/s]
# Processing Habropoda- tristissima-Isolated: 100%|███████| 5/5 [00:01<00:00,  2.62it/s]
# Processing folders:  75%|█████████████████████▊       | 12/16 [00:11<00:04,  1.02s/it]
# Processing Habroporda Depressa-Isolated:   0%|                 | 0/13 [00:00<?, ?it/s]
# Processing Habroporda Depressa-Isolated:   8%|▋        | 1/13 [00:00<00:05,  2.11it/s]
# Processing Habroporda Depressa-Isolated:  15%|█▍       | 2/13 [00:01<00:07,  1.48it/s]
# Processing Habroporda Depressa-Isolated:  23%|██       | 3/13 [00:01<00:04,  2.18it/s]
# Processing Habroporda Depressa-Isolated:  31%|██▊      | 4/13 [00:01<00:03,  2.93it/s]
# Processing Habroporda Depressa-Isolated:  38%|███▍     | 5/13 [00:02<00:02,  2.89it/s]
# Processing Habroporda Depressa-Isolated:  46%|████▏    | 6/13 [00:02<00:01,  3.56it/s]
# Processing Habroporda Depressa-Isolated:  54%|████▊    | 7/13 [00:02<00:01,  4.18it/s]
# Processing Habroporda Depressa-Isolated:  62%|█████▌   | 8/13 [00:02<00:01,  4.70it/s]
# Processing Habroporda Depressa-Isolated:  69%|██████▏  | 9/13 [00:02<00:00,  5.27it/s]
# Processing Habroporda Depressa-Isolated:  77%|██████▏ | 10/13 [00:02<00:00,  5.56it/s]
# Processing Habroporda Depressa-Isolated:  85%|██████▊ | 11/13 [00:02<00:00,  5.78it/s]
# Processing Habroporda Depressa-Isolated:  92%|███████▍| 12/13 [00:03<00:00,  6.21it/s]
# Processing Habroporda Depressa-Isolated: 100%|████████| 13/13 [00:03<00:00,  6.12it/s]
# Processing folders:  81%|███████████████████████▌     | 13/16 [00:14<00:05,  1.69s/it]
# Processing Megachile onobrychidis-isolated:   0%|               | 0/3 [00:00<?, ?it/s]
#
# Processing Osmia-Aglaia-Isolated:   0%|                         | 0/3 [00:00<?, ?it/s]
#
# Processing Xylocopa tabaniformis orpifex:   0%|                | 0/43 [00:00<?, ?it/s]
# Processing Xylocopa tabaniformis orpifex:   2%|▏       | 1/43 [00:00<00:10,  4.06it/s]
# Processing Xylocopa tabaniformis orpifex:   5%|▎       | 2/43 [00:00<00:09,  4.23it/s]
# Processing Xylocopa tabaniformis orpifex:   7%|▌       | 3/43 [00:00<00:08,  4.48it/s]
# Processing Xylocopa tabaniformis orpifex:   9%|▋       | 4/43 [00:00<00:08,  4.44it/s]
# Processing Xylocopa tabaniformis orpifex:  12%|▉       | 5/43 [00:01<00:09,  4.20it/s]
# Processing Xylocopa tabaniformis orpifex:  14%|█       | 6/43 [00:01<00:08,  4.28it/s]
# Processing Xylocopa tabaniformis orpifex:  16%|█▎      | 7/43 [00:01<00:08,  4.20it/s]
# Processing Xylocopa tabaniformis orpifex:  19%|█▍      | 8/43 [00:01<00:08,  4.28it/s]
# Processing Xylocopa tabaniformis orpifex:  21%|█▋      | 9/43 [00:02<00:08,  4.19it/s]
# Processing Xylocopa tabaniformis orpifex:  23%|█▋     | 10/43 [00:02<00:07,  4.37it/s]
# Processing Xylocopa tabaniformis orpifex:  26%|█▊     | 11/43 [00:02<00:07,  4.39it/s]
# Processing Xylocopa tabaniformis orpifex:  28%|█▉     | 12/43 [00:02<00:08,  3.60it/s]
# Processing Xylocopa tabaniformis orpifex:  30%|██     | 13/43 [00:03<00:07,  3.77it/s]
# Processing Xylocopa tabaniformis orpifex:  33%|██▎    | 14/43 [00:03<00:07,  3.64it/s]
# Processing Xylocopa tabaniformis orpifex:  35%|██▍    | 15/43 [00:03<00:06,  4.03it/s]
# Processing Xylocopa tabaniformis orpifex:  37%|██▌    | 16/43 [00:03<00:06,  4.27it/s]
# Processing Xylocopa tabaniformis orpifex:  40%|██▊    | 17/43 [00:04<00:06,  4.19it/s]
# Processing Xylocopa tabaniformis orpifex:  42%|██▉    | 18/43 [00:04<00:06,  4.15it/s]
# Processing Xylocopa tabaniformis orpifex:  44%|███    | 19/43 [00:04<00:05,  4.23it/s]
# Processing Xylocopa tabaniformis orpifex:  47%|███▎   | 20/43 [00:04<00:05,  4.27it/s]
# Processing Xylocopa tabaniformis orpifex:  49%|███▍   | 21/43 [00:05<00:05,  4.30it/s]
# Processing Xylocopa tabaniformis orpifex:  51%|███▌   | 22/43 [00:05<00:04,  4.45it/s]
# Processing Xylocopa tabaniformis orpifex:  53%|███▋   | 23/43 [00:05<00:04,  4.28it/s]
# Processing Xylocopa tabaniformis orpifex:  56%|███▉   | 24/43 [00:06<00:07,  2.53it/s]
# Processing Xylocopa tabaniformis orpifex:  58%|████   | 25/43 [00:06<00:06,  2.81it/s]
# Processing Xylocopa tabaniformis orpifex:  60%|████▏  | 26/43 [00:06<00:05,  2.91it/s]
# Processing Xylocopa tabaniformis orpifex:  63%|████▍  | 27/43 [00:07<00:07,  2.14it/s]
# Processing Xylocopa tabaniformis orpifex:  65%|████▌  | 28/43 [00:07<00:05,  2.51it/s]
# Processing Xylocopa tabaniformis orpifex:  67%|████▋  | 29/43 [00:08<00:04,  2.88it/s]
# Processing Xylocopa tabaniformis orpifex:  70%|████▉  | 30/43 [00:08<00:04,  3.02it/s]
# Processing Xylocopa tabaniformis orpifex:  72%|█████  | 31/43 [00:08<00:03,  3.22it/s]
# Processing Xylocopa tabaniformis orpifex:  74%|█████▏ | 32/43 [00:09<00:03,  2.99it/s]
# Processing Xylocopa tabaniformis orpifex:  77%|█████▎ | 33/43 [00:09<00:02,  3.33it/s]
# Processing Xylocopa tabaniformis orpifex:  79%|█████▌ | 34/43 [00:09<00:02,  3.55it/s]
# Processing Xylocopa tabaniformis orpifex:  81%|█████▋ | 35/43 [00:09<00:02,  3.42it/s]
# Processing Xylocopa tabaniformis orpifex:  84%|█████▊ | 36/43 [00:10<00:02,  3.10it/s]
# Processing Xylocopa tabaniformis orpifex:  86%|██████ | 37/43 [00:10<00:01,  3.39it/s]
# Processing Xylocopa tabaniformis orpifex:  88%|██████▏| 38/43 [00:10<00:01,  3.55it/s]
# Processing Xylocopa tabaniformis orpifex:  91%|██████▎| 39/43 [00:10<00:01,  3.75it/s]
# Processing Xylocopa tabaniformis orpifex:  93%|██████▌| 40/43 [00:11<00:00,  3.79it/s]
# Processing Xylocopa tabaniformis orpifex:  95%|██████▋| 41/43 [00:11<00:00,  3.50it/s]
# Processing Xylocopa tabaniformis orpifex:  98%|██████▊| 42/43 [00:11<00:00,  3.65it/s]
# Processing Xylocopa tabaniformis orpifex: 100%|███████| 43/43 [00:11<00:00,  4.03it/s]
# Processing folders: 100%|█████████████████████████████| 16/16 [00:26<00:00,  1.68s/it]
# Accuracy: 0.5357142857142857

# %% [markdown]
# We can see that our classification is not very effective with only an accuracy of about 0.54. Fine tuning the Support Vector Machine could present more accurate results. Below are descriptions of each parameter that can be altered.riance.

# %% [markdown]
# **1. Kernel Type:**
# kernel='poly': Polynomial kernel with parameters like degree and coef0.
# <br>
# kernel='rbf': Radial basis function (RBF) kernel with parameter gamma.
# <br>
# kernel='sigmoid': Sigmoid kernel with parameters gamma and coef0.

# %% [markdown]
# **2. Regularization Parameter (C):**
# <br>
# Adjust the regularization parameter C to control the trade-off between maximizing the margin and minimizing the classification error.
# <br>
# Higher values of C penalize misclassification more severely, which can lead to overfitting. Conversely, lower values of C encourage a wider margin but may increase bias.

# %% [markdown]
#  **3. Gamma Parameter (RBF Kernel):**
# If using an RBF kernel like we did initially, tune the gamma parameter, which determines the influence of each training example. Higher values of gamma lead to more complex decision boundaries, potentially causing overfitting. Lower values of gamma result in smoother decision boundaries, which may improve generalization.

# %% [markdown]
# Below, we ran the same model on all of the uncropped ARuCO marker images and the accuracy is extremely low. So we can conclude that spectral embedding does not provide the necessary computational power to preserve the complex structures in bee wings and output a strong classification accuracy. In the code below, the model is trained on 52 different species that correspond to a multitude of genera, so the dimensionality reduction technique may not be able to distinguish between species that share similar structures.

# %%
# Define a fixed size for resizing the images
image_size = (100, 100)  # Adjust as needed

# Initialize empty lists to store the resized image arrays and corresponding species identifiers
image_arrays = []
species_identifiers = []

# Define the path to the main folder
main_folder = "C:/Users/jenni/Downloads/Bee Wing Photos"


if not os.path.exists(main_folder):
    print(f"The path {main_folder} does not exist.")
else:
    # loop through each folder in the main folder
    for species_folder in tqdm(os.listdir(main_folder), desc="Processing folders"):
        species_folder_path = os.path.join(main_folder, species_folder)
        if os.path.isdir(species_folder_path):
            for image_file in tqdm(os.listdir(species_folder_path), desc=f"Processing {species_folder}", leave=False):
                # Skip files starting with '.'
                if not image_file.startswith('.'):
                    image_path = os.path.join(species_folder_path, image_file)
                    try:
                        with Image.open(image_path) as img:
                            # Ensure the image is in RGB mode
                            img = img.convert('RGB')
                            # Resize the image
                            img = img.resize(image_size, Image.BILINEAR)
                            # Convert to numpy array
                            image_array = np.array(img)
                            # Append the image array and species identifier to the lists
                            image_arrays.append(image_array)
                            species_identifiers.append(species_folder)
                    except Exception as e:
                        print(f"Error processing {image_path}: {e}")

    # ensure/resize all images so that they are the same shape before flattening

    image_arrays = [img for img in image_arrays if img.shape == (image_size[0], image_size[1], 3)]
    species_identifiers = [species_identifiers[i] for i in range(len(species_identifiers)) if image_arrays[i].shape == (image_size[0], image_size[1], 3)]
    
    if len(image_arrays) != len(species_identifiers):
        raise ValueError("Mismatch between number of valid images and species identifiers")

    # Create a DataFrame from the lists
    df = pd.DataFrame({'image_array': image_arrays, 'species_identifier': species_identifiers})

    # Flatten the image arrays
    # This transformation is necessary because most machine learning algorithms, including SVMs, operate on flat feature vectors rather than structured data like images. 
    # Flattening effectively "unrolls" the image pixels into a single vector, where each element represents the intensity value of a pixel.
    X = np.array([arr.flatten() for arr in df['image_array']])
    y = df['species_identifier']

    # Perform spectral embedding to extract features
    spectral_embedding = SpectralEmbedding(n_components=8, n_neighbors=10, random_state=42)
    X_embedding = spectral_embedding.fit_transform(X)

    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X_embedding, y, test_size=0.2, random_state=42)

    # Train a classifier (for example, Support Vector Machine)
    classifier = SVC(kernel='rbf', C=4.0, random_state=42, probability=True)
    classifier.fit(X_train, y_train)

    # Evaluate the classifier
    accuracy = classifier.score(X_test, y_test)
    print("Accuracy:", accuracy)

    # Visualize some random predictions
    plt.figure(figsize=(12, 6))
    random_indices = random.sample(range(len(X_test)), 10)
    for i, idx in enumerate(random_indices):
        plt.subplot(2, 5, i + 1)
        plt.imshow(df['image_array'].iloc[idx], interpolation='nearest')  # Use original color image
        predicted_probabilities = classifier.predict_proba([X_test[idx]])[0]
        top_three_indices = np.argsort(predicted_probabilities)[::-1][:3]
        top_three_species = [classifier.classes_[index] for index in top_three_indices]
        top_three_probs = [predicted_probabilities[index] for index in top_three_indices]
        plt.title('1st: {} ({:.2f}%)\n2nd: {} ({:.2f}%)\n3rd: {} ({:.2f}%)'.format(
            top_three_species[0], top_three_probs[0] * 100,
            top_three_species[1], top_three_probs[1] * 100,
            top_three_species[2], top_three_probs[2] * 100), fontsize=6)  # Set smaller font size for titles
        plt.xticks(())
        plt.yticks(())
    plt.suptitle('Classification of Images using SVM', fontsize=16)
    plt.show()
# Out:
# Processing folders:   0%|                                      | 0/52 [00:00<?, ?it/s]
# Processing Andrena candida:   0%|                               | 0/6 [00:00<?, ?it/s]
# Processing Andrena candida:  17%|███▊                   | 1/6 [00:00<00:00,  7.47it/s]
# Processing Andrena candida:  33%|███████▋               | 2/6 [00:00<00:00,  7.35it/s]
# Processing Andrena candida:  50%|███████████▌           | 3/6 [00:00<00:00,  7.52it/s]
# Processing Andrena candida:  67%|███████████████▎       | 4/6 [00:00<00:00,  7.56it/s]
# Processing Andrena candida:  83%|███████████████████▏   | 5/6 [00:00<00:00,  7.74it/s]
# Processing Andrena candida: 100%|███████████████████████| 6/6 [00:00<00:00,  7.49it/s]
# Processing folders:   2%|▌                             | 1/52 [00:00<00:40,  1.25it/s]
# Processing Andrena oenotherae:   0%|                            | 0/8 [00:00<?, ?it/s]
# Processing Andrena oenotherae:  12%|██▌                 | 1/8 [00:00<00:01,  6.12it/s]
# Processing Andrena oenotherae:  25%|█████               | 2/8 [00:00<00:00,  6.35it/s]
# Processing Andrena oenotherae:  38%|███████▌            | 3/8 [00:00<00:00,  6.77it/s]
# Processing Andrena oenotherae:  50%|██████████          | 4/8 [00:00<00:00,  6.88it/s]
# Processing Andrena oenotherae:  62%|████████████▌       | 5/8 [00:00<00:00,  7.01it/s]
# Processing Andrena oenotherae:  75%|███████████████     | 6/8 [00:00<00:00,  7.21it/s]
# Processing Andrena oenotherae:  88%|█████████████████▌  | 7/8 [00:01<00:00,  7.01it/s]
# Processing Andrena oenotherae: 100%|████████████████████| 8/8 [00:01<00:00,  7.01it/s]
# Processing folders:   4%|█▏                            | 2/52 [00:01<00:50,  1.01s/it]
# Processing Andrena principalis:   0%|                           | 0/6 [00:00<?, ?it/s]
# Processing Andrena principalis:  17%|███▏               | 1/6 [00:00<00:00,  6.19it/s]
# Processing Andrena principalis:  33%|██████▎            | 2/6 [00:00<00:00,  6.41it/s]
# Processing Andrena principalis:  50%|█████████▌         | 3/6 [00:00<00:00,  6.83it/s]
# Processing Andrena principalis:  67%|████████████▋      | 4/6 [00:00<00:00,  7.10it/s]
# Processing Andrena principalis:  83%|███████████████▊   | 5/6 [00:00<00:00,  7.21it/s]
# Processing Andrena principalis: 100%|███████████████████| 6/6 [00:00<00:00,  7.13it/s]
# Processing folders:   6%|█▋                            | 3/52 [00:02<00:46,  1.06it/s]
# Processing Anthidium collectum:   0%|                           | 0/2 [00:00<?, ?it/s]
# Processing Anthidium collectum:  50%|█████████▌         | 1/2 [00:00<00:00,  6.68it/s]
# Processing Anthidium collectum: 100%|███████████████████| 2/2 [00:00<00:00,  6.99it/s]
# Processing folders:   8%|██▎                           | 4/52 [00:03<00:33,  1.45it/s]
# Processing Anthidium palliventre:   0%|                         | 0/6 [00:00<?, ?it/s]
# Processing Anthidium palliventre:  17%|██▊              | 1/6 [00:00<00:00,  8.27it/s]
# Processing Anthidium palliventre:  33%|█████▋           | 2/6 [00:00<00:00,  7.89it/s]
# Processing Anthidium palliventre:  50%|████████▌        | 3/6 [00:00<00:00,  7.74it/s]
# Processing Anthidium palliventre:  67%|███████████▎     | 4/6 [00:00<00:00,  7.69it/s]
# Processing Anthidium palliventre:  83%|██████████████▏  | 5/6 [00:00<00:00,  7.77it/s]
# Processing Anthidium palliventre: 100%|█████████████████| 6/6 [00:00<00:00,  7.63it/s]
# Processing folders:  10%|██▉                           | 5/52 [00:03<00:33,  1.38it/s]
# Processing Anthophora californica:   0%|                        | 0/2 [00:00<?, ?it/s]
# Processing Anthophora californica:  50%|████████        | 1/2 [00:00<00:00,  6.55it/s]
# Processing Anthophora californica: 100%|████████████████| 2/2 [00:00<00:00,  7.15it/s]
# Processing folders:  12%|███▍                          | 6/52 [00:04<00:26,  1.74it/s]
# Processing Anthophora edwardsii:   0%|                          | 0/6 [00:00<?, ?it/s]
# Processing Anthophora edwardsii:  17%|███               | 1/6 [00:00<00:00,  7.77it/s]
# Processing Anthophora edwardsii:  33%|██████            | 2/6 [00:00<00:00,  7.85it/s]
# Processing Anthophora edwardsii:  50%|█████████         | 3/6 [00:00<00:00,  7.74it/s]
# Processing Anthophora edwardsii:  67%|████████████      | 4/6 [00:00<00:00,  7.75it/s]
# Processing Anthophora edwardsii:  83%|███████████████   | 5/6 [00:00<00:00,  6.84it/s]
# Processing Anthophora edwardsii: 100%|██████████████████| 6/6 [00:00<00:00,  6.75it/s]
# Processing folders:  13%|████                          | 7/52 [00:05<00:29,  1.51it/s]
# Processing Anthophora flavocincta:   0%|                        | 0/4 [00:00<?, ?it/s]
# Processing Anthophora flavocincta:  25%|████            | 1/4 [00:00<00:00,  7.75it/s]
# Processing Anthophora flavocincta:  50%|████████        | 2/4 [00:00<00:00,  8.00it/s]
# Processing Anthophora flavocincta:  75%|████████████    | 3/4 [00:00<00:00,  8.00it/s]
# Processing Anthophora flavocincta: 100%|████████████████| 4/4 [00:00<00:00,  7.95it/s]
# Processing folders:  15%|████▌                         | 8/52 [00:05<00:27,  1.63it/s]
# Processing Bombus californicus:   0%|                          | 0/22 [00:00<?, ?it/s]
# Processing Bombus californicus:   5%|▊                 | 1/22 [00:00<00:02,  7.71it/s]
# Processing Bombus californicus:   9%|█▋                | 2/22 [00:00<00:02,  7.80it/s]
# Processing Bombus californicus:  14%|██▍               | 3/22 [00:00<00:02,  6.86it/s]
# Processing Bombus californicus:  18%|███▎              | 4/22 [00:00<00:02,  6.78it/s]
# Processing Bombus californicus:  23%|████              | 5/22 [00:00<00:02,  7.16it/s]
# Processing Bombus californicus:  27%|████▉             | 6/22 [00:00<00:02,  7.10it/s]
# Processing Bombus californicus:  32%|█████▋            | 7/22 [00:00<00:01,  7.53it/s]
# Processing Bombus californicus:  36%|██████▌           | 8/22 [00:01<00:01,  7.79it/s]
# Processing Bombus californicus:  41%|███████▎          | 9/22 [00:01<00:01,  7.80it/s]
# Processing Bombus californicus:  45%|███████▋         | 10/22 [00:01<00:01,  7.58it/s]
# Processing Bombus californicus:  50%|████████▌        | 11/22 [00:01<00:01,  7.41it/s]
# Processing Bombus californicus:  55%|█████████▎       | 12/22 [00:01<00:01,  7.66it/s]
# Processing Bombus californicus:  59%|██████████       | 13/22 [00:01<00:01,  7.71it/s]
# Processing Bombus californicus:  64%|██████████▊      | 14/22 [00:01<00:01,  7.80it/s]
# Processing Bombus californicus:  68%|███████████▌     | 15/22 [00:01<00:00,  7.82it/s]
# Processing Bombus californicus:  73%|████████████▎    | 16/22 [00:02<00:00,  7.75it/s]
# Processing Bombus californicus:  77%|█████████████▏   | 17/22 [00:02<00:00,  7.47it/s]
# Processing Bombus californicus:  82%|█████████████▉   | 18/22 [00:02<00:00,  7.17it/s]
# Processing Bombus californicus:  86%|██████████████▋  | 19/22 [00:02<00:00,  6.74it/s]
# Processing Bombus californicus:  91%|███████████████▍ | 20/22 [00:02<00:00,  6.82it/s]
# Processing Bombus californicus:  95%|████████████████▏| 21/22 [00:02<00:00,  6.82it/s]
# Processing Bombus californicus: 100%|█████████████████| 22/22 [00:03<00:00,  6.90it/s]
# Processing folders:  17%|█████▏                        | 9/52 [00:08<00:58,  1.37s/it]
# Processing Bombus melanopygus:   0%|                            | 0/9 [00:00<?, ?it/s]
# Processing Bombus melanopygus:  11%|██▏                 | 1/9 [00:00<00:01,  6.96it/s]
# Processing Bombus melanopygus:  22%|████▍               | 2/9 [00:00<00:00,  7.22it/s]
# Processing Bombus melanopygus:  33%|██████▋             | 3/9 [00:00<00:00,  6.90it/s]
# Processing Bombus melanopygus:  44%|████████▉           | 4/9 [00:00<00:00,  7.00it/s]
# Processing Bombus melanopygus:  56%|███████████         | 5/9 [00:00<00:00,  6.87it/s]
# Processing Bombus melanopygus:  67%|█████████████▎      | 6/9 [00:00<00:00,  6.88it/s]
# Processing Bombus melanopygus:  78%|███████████████▌    | 7/9 [00:01<00:00,  6.84it/s]
# Processing Bombus melanopygus:  89%|█████████████████▊  | 8/9 [00:01<00:00,  6.76it/s]
# Processing Bombus melanopygus: 100%|████████████████████| 9/9 [00:01<00:00,  6.82it/s]
# Processing folders:  19%|█████▌                       | 10/52 [00:09<00:56,  1.35s/it]
# Processing Bombus sonorus:   0%|                               | 0/11 [00:00<?, ?it/s]
# Processing Bombus sonorus:   9%|██                     | 1/11 [00:00<00:01,  6.21it/s]
# Processing Bombus sonorus:  18%|████▏                  | 2/11 [00:00<00:01,  6.92it/s]
# Processing Bombus sonorus:  27%|██████▎                | 3/11 [00:00<00:01,  7.21it/s]
# Processing Bombus sonorus:  36%|████████▎              | 4/11 [00:00<00:00,  7.34it/s]
# Processing Bombus sonorus:  45%|██████████▍            | 5/11 [00:00<00:00,  7.14it/s]
# Processing Bombus sonorus:  55%|████████████▌          | 6/11 [00:00<00:00,  7.25it/s]
# Processing Bombus sonorus:  64%|██████████████▋        | 7/11 [00:00<00:00,  7.26it/s]
# Processing Bombus sonorus:  73%|████████████████▋      | 8/11 [00:01<00:00,  7.07it/s]
# Processing Bombus sonorus:  82%|██████████████████▊    | 9/11 [00:01<00:00,  7.16it/s]
# Processing Bombus sonorus:  91%|████████████████████  | 10/11 [00:01<00:00,  7.04it/s]
# Processing Bombus sonorus: 100%|██████████████████████| 11/11 [00:01<00:00,  7.27it/s]
# Processing folders:  21%|██████▏                      | 11/52 [00:11<00:57,  1.41s/it]
# Processing Bombus terricola:   0%|                              | 0/4 [00:00<?, ?it/s]
# Processing Bombus terricola:  25%|█████▌                | 1/4 [00:00<00:00,  8.68it/s]
# Processing Bombus terricola:  50%|███████████           | 2/4 [00:00<00:00,  7.36it/s]
# Processing Bombus terricola:  75%|████████████████▌     | 3/4 [00:00<00:00,  7.51it/s]
# Processing Bombus terricola: 100%|██████████████████████| 4/4 [00:00<00:00,  6.80it/s]
# Processing folders:  23%|██████▋                      | 12/52 [00:12<00:46,  1.15s/it]
# Processing Bombus vagans:   0%|                                 | 0/6 [00:00<?, ?it/s]
# Processing Bombus vagans:  17%|████▏                    | 1/6 [00:00<00:00,  6.43it/s]
# Processing Bombus vagans:  33%|████████▎                | 2/6 [00:00<00:00,  6.84it/s]
# Processing Bombus vagans:  50%|████████████▌            | 3/6 [00:00<00:00,  7.16it/s]
# Processing Bombus vagans:  67%|████████████████▋        | 4/6 [00:00<00:00,  7.25it/s]
# Processing Bombus vagans:  83%|████████████████████▊    | 5/6 [00:00<00:00,  6.79it/s]
# Processing Bombus vagans: 100%|█████████████████████████| 6/6 [00:00<00:00,  6.43it/s]
# Processing folders:  25%|███████▎                     | 13/52 [00:12<00:42,  1.08s/it]
# Processing Ceratina punctagena:   0%|                           | 0/2 [00:00<?, ?it/s]
# Processing Ceratina punctagena:  50%|█████████▌         | 1/2 [00:00<00:00,  5.90it/s]
# Processing Ceratina punctagena: 100%|███████████████████| 2/2 [00:00<00:00,  6.36it/s]
# Processing folders:  27%|███████▊                     | 14/52 [00:13<00:32,  1.18it/s]
# Processing Diadasia australis:   0%|                            | 0/2 [00:00<?, ?it/s]
# Processing Diadasia australis:  50%|██████████          | 1/2 [00:00<00:00,  7.88it/s]
# Processing Diadasia australis: 100%|████████████████████| 2/2 [00:00<00:00,  7.86it/s]
# Processing folders:  29%|████████▎                    | 15/52 [00:13<00:24,  1.49it/s]
# Processing Diadasia bituberculata:   0%|                       | 0/20 [00:00<?, ?it/s]
# Processing Diadasia bituberculata:   5%|▊              | 1/20 [00:00<00:02,  7.60it/s]
# Processing Diadasia bituberculata:  10%|█▌             | 2/20 [00:00<00:02,  7.78it/s]
# Processing Diadasia bituberculata:  15%|██▎            | 3/20 [00:00<00:02,  7.79it/s]
# Processing Diadasia bituberculata:  20%|███            | 4/20 [00:00<00:02,  7.29it/s]
# Processing Diadasia bituberculata:  25%|███▊           | 5/20 [00:00<00:02,  7.34it/s]
# Processing Diadasia bituberculata:  30%|████▌          | 6/20 [00:00<00:02,  6.60it/s]
# Processing Diadasia bituberculata:  35%|█████▎         | 7/20 [00:00<00:01,  6.69it/s]
# Processing Diadasia bituberculata:  40%|██████         | 8/20 [00:01<00:01,  6.60it/s]
# Processing Diadasia bituberculata:  45%|██████▊        | 9/20 [00:01<00:01,  6.72it/s]
# Processing Diadasia bituberculata:  50%|███████       | 10/20 [00:01<00:01,  6.46it/s]
# Processing Diadasia bituberculata:  55%|███████▋      | 11/20 [00:01<00:01,  6.60it/s]
# Processing Diadasia bituberculata:  60%|████████▍     | 12/20 [00:01<00:01,  6.62it/s]
# Processing Diadasia bituberculata:  65%|█████████     | 13/20 [00:01<00:01,  6.62it/s]
# Processing Diadasia bituberculata:  70%|█████████▊    | 14/20 [00:02<00:00,  6.81it/s]
# Processing Diadasia bituberculata:  75%|██████████▌   | 15/20 [00:02<00:00,  6.86it/s]
# Processing Diadasia bituberculata:  80%|███████████▏  | 16/20 [00:02<00:00,  6.87it/s]
# Processing Diadasia bituberculata:  85%|███████████▉  | 17/20 [00:02<00:00,  7.11it/s]
# Processing Diadasia bituberculata:  90%|████████████▌ | 18/20 [00:02<00:00,  7.34it/s]
# Processing Diadasia bituberculata:  95%|█████████████▎| 19/20 [00:02<00:00,  7.02it/s]
# Processing Diadasia bituberculata: 100%|██████████████| 20/20 [00:02<00:00,  7.02it/s]
# Processing folders:  31%|████████▉                    | 16/52 [00:16<00:48,  1.34s/it]
# Processing Diadasia diminuta:   0%|                             | 0/4 [00:00<?, ?it/s]
# Processing Diadasia diminuta:  25%|█████▎               | 1/4 [00:00<00:00,  6.41it/s]
# Processing Diadasia diminuta:  50%|██████████▌          | 2/4 [00:00<00:00,  6.96it/s]
# Processing Diadasia diminuta:  75%|███████████████▊     | 3/4 [00:00<00:00,  7.02it/s]
# Processing Diadasia diminuta: 100%|█████████████████████| 4/4 [00:00<00:00,  7.02it/s]
# Processing folders:  33%|█████████▍                   | 17/52 [00:16<00:38,  1.11s/it]
# Processing Diadasia enavata:   0%|                              | 0/2 [00:00<?, ?it/s]
# Processing Diadasia enavata:  50%|███████████           | 1/2 [00:00<00:00,  7.31it/s]
# Processing Diadasia enavata: 100%|██████████████████████| 2/2 [00:00<00:00,  7.37it/s]
# Processing folders:  35%|██████████                   | 18/52 [00:17<00:29,  1.16it/s]
# Processing Diadasia laticauda:   0%|                            | 0/2 [00:00<?, ?it/s]
# Processing Diadasia laticauda:  50%|██████████          | 1/2 [00:00<00:00,  6.66it/s]
# Processing Diadasia laticauda: 100%|████████████████████| 2/2 [00:00<00:00,  6.87it/s]
# Processing folders:  37%|██████████▌                  | 19/52 [00:17<00:22,  1.44it/s]
# Processing Diadasia nigrifrons:   0%|                           | 0/4 [00:00<?, ?it/s]
# Processing Diadasia nigrifrons:  25%|████▊              | 1/4 [00:00<00:00,  7.16it/s]
# Processing Diadasia nigrifrons:  50%|█████████▌         | 2/4 [00:00<00:00,  7.19it/s]
# Processing Diadasia nigrifrons:  75%|██████████████▎    | 3/4 [00:00<00:00,  7.21it/s]
# Processing Diadasia nigrifrons: 100%|███████████████████| 4/4 [00:00<00:00,  7.07it/s]
# Processing folders:  38%|███████████▏                 | 20/52 [00:18<00:20,  1.53it/s]
# Processing Diadasia ochracea:   0%|                            | 0/24 [00:00<?, ?it/s]
# Processing Diadasia ochracea:   4%|▊                   | 1/24 [00:00<00:03,  7.04it/s]
# Processing Diadasia ochracea:   8%|█▋                  | 2/24 [00:00<00:03,  7.33it/s]
# Processing Diadasia ochracea:  12%|██▌                 | 3/24 [00:00<00:02,  7.11it/s]
# Processing Diadasia ochracea:  17%|███▎                | 4/24 [00:00<00:02,  7.19it/s]
# Processing Diadasia ochracea:  21%|████▏               | 5/24 [00:00<00:02,  7.23it/s]
# Processing Diadasia ochracea:  25%|█████               | 6/24 [00:00<00:02,  7.16it/s]
# Processing Diadasia ochracea:  29%|█████▊              | 7/24 [00:00<00:02,  7.13it/s]
# Processing Diadasia ochracea:  33%|██████▋             | 8/24 [00:01<00:02,  7.29it/s]
# Processing Diadasia ochracea:  38%|███████▌            | 9/24 [00:01<00:02,  7.15it/s]
# Processing Diadasia ochracea:  42%|███████▉           | 10/24 [00:01<00:01,  7.11it/s]
# Processing Diadasia ochracea:  46%|████████▋          | 11/24 [00:01<00:01,  7.07it/s]
# Processing Diadasia ochracea:  50%|█████████▌         | 12/24 [00:01<00:01,  7.07it/s]
# Processing Diadasia ochracea:  54%|██████████▎        | 13/24 [00:01<00:01,  7.09it/s]
# Processing Diadasia ochracea:  58%|███████████        | 14/24 [00:01<00:01,  7.19it/s]
# Processing Diadasia ochracea:  62%|███████████▉       | 15/24 [00:02<00:01,  6.95it/s]
# Processing Diadasia ochracea:  67%|████████████▋      | 16/24 [00:02<00:01,  7.06it/s]
# Processing Diadasia ochracea:  71%|█████████████▍     | 17/24 [00:02<00:00,  7.20it/s]
# Processing Diadasia ochracea:  75%|██████████████▎    | 18/24 [00:02<00:00,  7.29it/s]
# Processing Diadasia ochracea:  79%|███████████████    | 19/24 [00:02<00:00,  7.35it/s]
# Processing Diadasia ochracea:  83%|███████████████▊   | 20/24 [00:02<00:00,  7.39it/s]
# Processing Diadasia ochracea:  88%|████████████████▋  | 21/24 [00:02<00:00,  7.38it/s]
# Processing Diadasia ochracea:  92%|█████████████████▍ | 22/24 [00:03<00:00,  7.27it/s]
# Processing Diadasia ochracea:  96%|██████████████████▏| 23/24 [00:03<00:00,  7.22it/s]
# Processing Diadasia ochracea: 100%|███████████████████| 24/24 [00:03<00:00,  6.30it/s]
# Processing folders:  40%|███████████▋                 | 21/52 [00:21<00:45,  1.48s/it]
# Processing Diadasia rinconis:   0%|                            | 0/17 [00:00<?, ?it/s]
# Processing Diadasia rinconis:   6%|█▏                  | 1/17 [00:00<00:02,  6.96it/s]
# Processing Diadasia rinconis:  12%|██▎                 | 2/17 [00:00<00:02,  6.73it/s]
# Processing Diadasia rinconis:  18%|███▌                | 3/17 [00:00<00:02,  6.87it/s]
# Processing Diadasia rinconis:  24%|████▋               | 4/17 [00:00<00:01,  6.87it/s]
# Processing Diadasia rinconis:  29%|█████▉              | 5/17 [00:00<00:01,  6.82it/s]
# Processing Diadasia rinconis:  35%|███████             | 6/17 [00:00<00:01,  7.02it/s]
# Processing Diadasia rinconis:  41%|████████▏           | 7/17 [00:01<00:01,  6.93it/s]
# Processing Diadasia rinconis:  47%|█████████▍          | 8/17 [00:01<00:01,  6.90it/s]
# Processing Diadasia rinconis:  53%|██████████▌         | 9/17 [00:01<00:01,  7.06it/s]
# Processing Diadasia rinconis:  59%|███████████▏       | 10/17 [00:01<00:01,  6.85it/s]
# Processing Diadasia rinconis:  65%|████████████▎      | 11/17 [00:01<00:00,  6.76it/s]
# Processing Diadasia rinconis:  71%|█████████████▍     | 12/17 [00:01<00:00,  6.72it/s]
# Processing Diadasia rinconis:  76%|██████████████▌    | 13/17 [00:01<00:00,  6.78it/s]
# Processing Diadasia rinconis:  82%|███████████████▋   | 14/17 [00:02<00:00,  6.70it/s]
# Processing Diadasia rinconis:  88%|████████████████▊  | 15/17 [00:02<00:00,  6.95it/s]
# Processing Diadasia rinconis:  94%|█████████████████▉ | 16/17 [00:02<00:00,  6.87it/s]
# Processing Diadasia rinconis: 100%|███████████████████| 17/17 [00:02<00:00,  6.78it/s]
# Processing folders:  42%|████████████▎                | 22/52 [00:24<00:53,  1.78s/it]
# Processing Eucera actuosa:   0%|                               | 0/24 [00:00<?, ?it/s]
# Processing Eucera actuosa:   4%|▉                      | 1/24 [00:00<00:03,  6.50it/s]
# Processing Eucera actuosa:   8%|█▉                     | 2/24 [00:00<00:03,  6.61it/s]
# Processing Eucera actuosa:  12%|██▉                    | 3/24 [00:00<00:03,  6.44it/s]
# Processing Eucera actuosa:  17%|███▊                   | 4/24 [00:00<00:03,  6.60it/s]
# Processing Eucera actuosa:  21%|████▊                  | 5/24 [00:00<00:02,  7.03it/s]
# Processing Eucera actuosa:  25%|█████▊                 | 6/24 [00:00<00:02,  6.89it/s]
# Processing Eucera actuosa:  29%|██████▋                | 7/24 [00:01<00:02,  7.19it/s]
# Processing Eucera actuosa:  33%|███████▋               | 8/24 [00:01<00:02,  7.05it/s]
# Processing Eucera actuosa:  38%|████████▋              | 9/24 [00:01<00:02,  7.00it/s]
# Processing Eucera actuosa:  42%|█████████▏            | 10/24 [00:01<00:01,  7.18it/s]
# Processing Eucera actuosa:  46%|██████████            | 11/24 [00:01<00:01,  7.05it/s]
# Processing Eucera actuosa:  50%|███████████           | 12/24 [00:01<00:01,  6.89it/s]
# Processing Eucera actuosa:  54%|███████████▉          | 13/24 [00:01<00:01,  6.85it/s]
# Processing Eucera actuosa:  58%|████████████▊         | 14/24 [00:02<00:01,  6.93it/s]
# Processing Eucera actuosa:  62%|█████████████▊        | 15/24 [00:02<00:01,  7.14it/s]
# Processing Eucera actuosa:  67%|██████████████▋       | 16/24 [00:02<00:01,  7.04it/s]
# Processing Eucera actuosa:  71%|███████████████▌      | 17/24 [00:02<00:00,  7.01it/s]
# Processing Eucera actuosa:  75%|████████████████▌     | 18/24 [00:02<00:00,  7.13it/s]
# Processing Eucera actuosa:  79%|█████████████████▍    | 19/24 [00:02<00:00,  7.34it/s]
# Processing Eucera actuosa:  83%|██████████████████▎   | 20/24 [00:02<00:00,  7.50it/s]
# Processing Eucera actuosa:  88%|███████████████████▎  | 21/24 [00:02<00:00,  7.58it/s]
# Processing Eucera actuosa:  92%|████████████████████▏ | 22/24 [00:03<00:00,  7.59it/s]
# Processing Eucera actuosa:  96%|█████████████████████ | 23/24 [00:03<00:00,  7.48it/s]
# Processing Eucera actuosa: 100%|██████████████████████| 24/24 [00:03<00:00,  6.87it/s]
# Processing folders:  44%|████████████▊                | 23/52 [00:27<01:05,  2.27s/it]
# Processing Eucera edwardsii:   0%|                              | 0/4 [00:00<?, ?it/s]
# Processing Eucera edwardsii:  25%|█████▌                | 1/4 [00:00<00:00,  4.44it/s]
# Processing Eucera edwardsii:  50%|███████████           | 2/4 [00:00<00:00,  5.64it/s]
# Processing Eucera edwardsii:  75%|████████████████▌     | 3/4 [00:00<00:00,  6.21it/s]
# Processing Eucera edwardsii: 100%|██████████████████████| 4/4 [00:00<00:00,  6.56it/s]
# Processing folders:  46%|█████████████▍               | 24/52 [00:28<00:50,  1.79s/it]
# Processing Eucera frater albopilosa:   0%|                      | 0/4 [00:00<?, ?it/s]
# Processing Eucera frater albopilosa:  25%|███▌          | 1/4 [00:00<00:00,  6.99it/s]
# Processing Eucera frater albopilosa:  50%|███████       | 2/4 [00:00<00:00,  7.32it/s]
# Processing Eucera frater albopilosa:  75%|██████████▌   | 3/4 [00:00<00:00,  7.37it/s]
# Processing Eucera frater albopilosa: 100%|██████████████| 4/4 [00:00<00:00,  7.02it/s]
# Processing folders:  48%|█████████████▉               | 25/52 [00:28<00:38,  1.42s/it]
# Processing Euglossa sp:   0%|                                   | 0/2 [00:00<?, ?it/s]
# Processing Euglossa sp:  50%|█████████████▌             | 1/2 [00:00<00:00,  7.72it/s]
# Processing Euglossa sp: 100%|███████████████████████████| 2/2 [00:00<00:00,  7.88it/s]
# Processing folders:  50%|██████████████▌              | 26/52 [00:28<00:27,  1.07s/it]
# Processing Habropoda depressa:   0%|                           | 0/15 [00:00<?, ?it/s]
# Processing Habropoda depressa:   7%|█▎                 | 1/15 [00:00<00:01,  7.42it/s]
# Processing Habropoda depressa:  13%|██▌                | 2/15 [00:00<00:01,  7.15it/s]
# Processing Habropoda depressa:  20%|███▊               | 3/15 [00:00<00:01,  7.38it/s]
# Processing Habropoda depressa:  27%|█████              | 4/15 [00:00<00:01,  7.41it/s]
# Processing Habropoda depressa:  33%|██████▎            | 5/15 [00:00<00:01,  7.46it/s]
# Processing Habropoda depressa:  40%|███████▌           | 6/15 [00:00<00:01,  7.53it/s]
# Processing Habropoda depressa:  47%|████████▊          | 7/15 [00:00<00:01,  7.44it/s]
# Processing Habropoda depressa:  53%|██████████▏        | 8/15 [00:01<00:00,  7.57it/s]
# Processing Habropoda depressa:  60%|███████████▍       | 9/15 [00:01<00:00,  7.45it/s]
# Processing Habropoda depressa:  67%|████████████      | 10/15 [00:01<00:00,  7.56it/s]
# Processing Habropoda depressa:  73%|█████████████▏    | 11/15 [00:01<00:00,  7.40it/s]
# Processing Habropoda depressa:  80%|██████████████▍   | 12/15 [00:01<00:00,  7.26it/s]
# Processing Habropoda depressa:  87%|███████████████▌  | 13/15 [00:01<00:00,  7.38it/s]
# Processing Habropoda depressa:  93%|████████████████▊ | 14/15 [00:01<00:00,  7.38it/s]
# Processing Habropoda depressa: 100%|██████████████████| 15/15 [00:02<00:00,  7.41it/s]
# Processing folders:  52%|███████████████              | 27/52 [00:30<00:33,  1.36s/it]
# Processing Habropoda tristissima:   0%|                         | 0/4 [00:00<?, ?it/s]
# Processing Habropoda tristissima:  25%|████▎            | 1/4 [00:00<00:00,  7.62it/s]
# Processing Habropoda tristissima:  50%|████████▌        | 2/4 [00:00<00:00,  7.62it/s]
# Processing Habropoda tristissima:  75%|████████████▊    | 3/4 [00:00<00:00,  7.83it/s]
# Processing Habropoda tristissima: 100%|█████████████████| 4/4 [00:00<00:00,  7.87it/s]
# Processing folders:  54%|███████████████▌             | 28/52 [00:31<00:26,  1.11s/it]
# Processing Halictus farinosus:   0%|                           | 0/18 [00:00<?, ?it/s]
# Processing Halictus farinosus:   6%|█                  | 1/18 [00:00<00:02,  8.16it/s]
# Processing Halictus farinosus:  11%|██                 | 2/18 [00:00<00:02,  7.83it/s]
# Processing Halictus farinosus:  17%|███▏               | 3/18 [00:00<00:02,  7.26it/s]
# Processing Halictus farinosus:  22%|████▏              | 4/18 [00:00<00:01,  7.08it/s]
# Processing Halictus farinosus:  28%|█████▎             | 5/18 [00:00<00:01,  6.99it/s]
# Processing Halictus farinosus:  33%|██████▎            | 6/18 [00:00<00:01,  6.98it/s]
# Processing Halictus farinosus:  39%|███████▍           | 7/18 [00:00<00:01,  6.90it/s]
# Processing Halictus farinosus:  44%|████████▍          | 8/18 [00:01<00:01,  7.10it/s]
# Processing Halictus farinosus:  50%|█████████▌         | 9/18 [00:01<00:01,  7.09it/s]
# Processing Halictus farinosus:  56%|██████████        | 10/18 [00:01<00:01,  6.43it/s]
# Processing Halictus farinosus:  61%|███████████       | 11/18 [00:01<00:01,  6.29it/s]
# Processing Halictus farinosus:  67%|████████████      | 12/18 [00:01<00:00,  6.15it/s]
# Processing Halictus farinosus:  72%|█████████████     | 13/18 [00:02<00:01,  4.67it/s]
# Processing Halictus farinosus:  78%|██████████████    | 14/18 [00:02<00:00,  5.18it/s]
# Processing Halictus farinosus:  83%|███████████████   | 15/18 [00:02<00:00,  5.68it/s]
# Processing Halictus farinosus:  89%|████████████████  | 16/18 [00:02<00:00,  6.00it/s]
# Processing Halictus farinosus:  94%|█████████████████ | 17/18 [00:02<00:00,  6.47it/s]
# Processing Halictus farinosus: 100%|██████████████████| 18/18 [00:02<00:00,  6.73it/s]
# Processing folders:  56%|████████████████▏            | 29/52 [00:34<00:37,  1.62s/it]
# Processing Halictus ligatus:   0%|                              | 0/2 [00:00<?, ?it/s]
# Processing Halictus ligatus:  50%|███████████           | 1/2 [00:00<00:00,  7.26it/s]
# Processing Halictus ligatus: 100%|██████████████████████| 2/2 [00:00<00:00,  7.39it/s]
# Processing folders:  58%|████████████████▋            | 30/52 [00:34<00:26,  1.22s/it]
# Processing Halictus rubicundus:   0%|                           | 0/4 [00:00<?, ?it/s]
# Processing Halictus rubicundus:  25%|████▊              | 1/4 [00:00<00:00,  7.77it/s]
# Processing Halictus rubicundus:  50%|█████████▌         | 2/4 [00:00<00:00,  6.96it/s]
# Processing Halictus rubicundus:  75%|██████████████▎    | 3/4 [00:00<00:00,  7.14it/s]
# Processing Halictus rubicundus: 100%|███████████████████| 4/4 [00:00<00:00,  7.23it/s]
# Processing folders:  60%|█████████████████▎           | 31/52 [00:35<00:21,  1.02s/it]
# Processing Lasioglossum kincaidii:   0%|                       | 0/10 [00:00<?, ?it/s]
# Processing Lasioglossum kincaidii:  10%|█▌             | 1/10 [00:00<00:01,  7.09it/s]
# Processing Lasioglossum kincaidii:  20%|███            | 2/10 [00:00<00:01,  7.23it/s]
# Processing Lasioglossum kincaidii:  30%|████▌          | 3/10 [00:00<00:00,  7.88it/s]
# Processing Lasioglossum kincaidii:  40%|██████         | 4/10 [00:00<00:00,  8.43it/s]
# Processing Lasioglossum kincaidii:  50%|███████▌       | 5/10 [00:00<00:00,  8.19it/s]
# Processing Lasioglossum kincaidii:  60%|█████████      | 6/10 [00:00<00:00,  8.03it/s]
# Processing Lasioglossum kincaidii:  70%|██████████▌    | 7/10 [00:00<00:00,  8.02it/s]
# Processing Lasioglossum kincaidii:  80%|████████████   | 8/10 [00:00<00:00,  8.46it/s]
# Processing Lasioglossum kincaidii:  90%|█████████████▌ | 9/10 [00:01<00:00,  8.01it/s]
# Processing Lasioglossum kincaidii: 100%|██████████████| 10/10 [00:01<00:00,  7.83it/s]
# Processing folders:  62%|█████████████████▊           | 32/52 [00:36<00:21,  1.09s/it]
# Processing Lasioglossum pacificum:   0%|                        | 0/2 [00:00<?, ?it/s]
# Processing Lasioglossum pacificum:  50%|████████        | 1/2 [00:00<00:00,  7.26it/s]
# Processing Lasioglossum pacificum: 100%|████████████████| 2/2 [00:00<00:00,  7.46it/s]
# Processing folders:  63%|██████████████████▍          | 33/52 [00:36<00:16,  1.18it/s]
# Processing Megachile anograe:   0%|                             | 0/2 [00:00<?, ?it/s]
# Processing Megachile anograe:  50%|██████████▌          | 1/2 [00:00<00:00,  6.90it/s]
# Processing Megachile anograe: 100%|█████████████████████| 2/2 [00:00<00:00,  6.99it/s]
# Processing folders:  65%|██████████████████▉          | 34/52 [00:36<00:12,  1.47it/s]
# Processing Megachile fidelis:   0%|                             | 0/2 [00:00<?, ?it/s]
# Processing Megachile fidelis:  50%|██████████▌          | 1/2 [00:00<00:00,  7.40it/s]
# Processing Megachile fidelis: 100%|█████████████████████| 2/2 [00:00<00:00,  7.42it/s]
# Processing folders:  67%|███████████████████▌         | 35/52 [00:37<00:09,  1.79it/s]
# Processing Megachile onobrychidis:   0%|                        | 0/2 [00:00<?, ?it/s]
# Processing Megachile onobrychidis:  50%|████████        | 1/2 [00:00<00:00,  8.29it/s]
# Processing Megachile onobrychidis: 100%|████████████████| 2/2 [00:00<00:00,  8.15it/s]
# Processing folders:  69%|████████████████████         | 36/52 [00:37<00:07,  2.14it/s]
# Processing Megachile perihirta:   0%|                           | 0/2 [00:00<?, ?it/s]
# Processing Megachile perihirta:  50%|█████████▌         | 1/2 [00:00<00:00,  6.46it/s]
# Processing Megachile perihirta: 100%|███████████████████| 2/2 [00:00<00:00,  6.74it/s]
# Processing folders:  71%|████████████████████▋        | 37/52 [00:37<00:06,  2.39it/s]
# Processing Megachile rotundata:   0%|                           | 0/2 [00:00<?, ?it/s]
# Processing Megachile rotundata:  50%|█████████▌         | 1/2 [00:00<00:00,  7.63it/s]
# Processing Megachile rotundata: 100%|███████████████████| 2/2 [00:00<00:00,  7.35it/s]
# Processing folders:  73%|█████████████████████▏       | 38/52 [00:38<00:05,  2.66it/s]
# Processing Megachile texana:   0%|                              | 0/2 [00:00<?, ?it/s]
# Processing Megachile texana:  50%|███████████           | 1/2 [00:00<00:00,  7.81it/s]
# Processing Megachile texana: 100%|██████████████████████| 2/2 [00:00<00:00,  6.80it/s]
# Processing folders:  75%|█████████████████████▊       | 39/52 [00:38<00:04,  2.85it/s]
# Processing Melissodes lustrus:   0%|                            | 0/2 [00:00<?, ?it/s]
# Processing Melissodes lustrus:  50%|██████████          | 1/2 [00:00<00:00,  7.05it/s]
# Processing Melissodes lustrus: 100%|████████████████████| 2/2 [00:00<00:00,  7.50it/s]
# Processing folders:  77%|██████████████████████▎      | 40/52 [00:38<00:03,  3.06it/s]
# Processing Melissodes tepida timberlakei:   0%|                 | 0/8 [00:00<?, ?it/s]
# Processing Melissodes tepida timberlakei:  12%|█▏       | 1/8 [00:00<00:00,  7.93it/s]
# Processing Melissodes tepida timberlakei:  25%|██▎      | 2/8 [00:00<00:00,  7.79it/s]
# Processing Melissodes tepida timberlakei:  38%|███▍     | 3/8 [00:00<00:00,  7.81it/s]
# Processing Melissodes tepida timberlakei:  50%|████▌    | 4/8 [00:00<00:00,  7.39it/s]
# Processing Melissodes tepida timberlakei:  62%|█████▋   | 5/8 [00:00<00:00,  7.43it/s]
# Processing Melissodes tepida timberlakei:  75%|██████▊  | 6/8 [00:00<00:00,  7.56it/s]
# Processing Melissodes tepida timberlakei:  88%|███████▉ | 7/8 [00:00<00:00,  7.81it/s]
# Processing Melissodes tepida timberlakei: 100%|█████████| 8/8 [00:01<00:00,  7.82it/s]
# Processing folders:  79%|██████████████████████▊      | 41/52 [00:39<00:05,  1.84it/s]
# Processing Osmia aglaia:   0%|                                  | 0/2 [00:00<?, ?it/s]
# Processing Osmia aglaia:  50%|█████████████             | 1/2 [00:00<00:00,  7.57it/s]
# Processing Osmia aglaia: 100%|██████████████████████████| 2/2 [00:00<00:00,  7.75it/s]
# Processing folders:  81%|███████████████████████▍     | 42/52 [00:39<00:04,  2.18it/s]
# Processing Osmia atrocyanea:   0%|                              | 0/4 [00:00<?, ?it/s]
# Processing Osmia atrocyanea:  25%|█████▌                | 1/4 [00:00<00:00,  5.75it/s]
# Processing Osmia atrocyanea:  50%|███████████           | 2/4 [00:00<00:00,  6.47it/s]
# Processing Osmia atrocyanea:  75%|████████████████▌     | 3/4 [00:00<00:00,  7.03it/s]
# Processing Osmia atrocyanea: 100%|██████████████████████| 4/4 [00:00<00:00,  7.33it/s]
# Processing folders:  83%|███████████████████████▉     | 43/52 [00:40<00:04,  2.02it/s]
# Processing Osmia brevis:   0%|                                  | 0/2 [00:00<?, ?it/s]
# Processing Osmia brevis:  50%|█████████████             | 1/2 [00:00<00:00,  7.71it/s]
# Processing Osmia brevis: 100%|██████████████████████████| 2/2 [00:00<00:00,  7.88it/s]
# Processing folders:  85%|████████████████████████▌    | 44/52 [00:40<00:03,  2.36it/s]
# Processing Osmia californica:   0%|                             | 0/2 [00:00<?, ?it/s]
# Processing Osmia californica:  50%|██████████▌          | 1/2 [00:00<00:00,  6.36it/s]
# Processing Osmia californica: 100%|█████████████████████| 2/2 [00:00<00:00,  6.66it/s]
# Processing folders:  87%|█████████████████████████    | 45/52 [00:41<00:02,  2.57it/s]
# Processing Osmia clarescens:   0%|                              | 0/8 [00:00<?, ?it/s]
# Processing Osmia clarescens:  12%|██▊                   | 1/8 [00:00<00:00,  7.44it/s]
# Processing Osmia clarescens:  25%|█████▌                | 2/8 [00:00<00:00,  7.97it/s]
# Processing Osmia clarescens:  38%|████████▎             | 3/8 [00:00<00:00,  7.70it/s]
# Processing Osmia clarescens:  50%|███████████           | 4/8 [00:00<00:00,  7.71it/s]
# Processing Osmia clarescens:  62%|█████████████▊        | 5/8 [00:00<00:00,  7.45it/s]
# Processing Osmia clarescens:  75%|████████████████▌     | 6/8 [00:00<00:00,  7.45it/s]
# Processing Osmia clarescens:  88%|███████████████████▎  | 7/8 [00:00<00:00,  7.71it/s]
# Processing Osmia clarescens: 100%|██████████████████████| 8/8 [00:01<00:00,  7.81it/s]
# Processing folders:  88%|█████████████████████████▋   | 46/52 [00:42<00:03,  1.71it/s]
# Processing Osmia coloradensis:   0%|                           | 0/10 [00:00<?, ?it/s]
# Processing Osmia coloradensis:  10%|█▉                 | 1/10 [00:00<00:01,  8.23it/s]
# Processing Osmia coloradensis:  20%|███▊               | 2/10 [00:00<00:00,  8.07it/s]
# Processing Osmia coloradensis:  30%|█████▋             | 3/10 [00:00<00:00,  7.34it/s]
# Processing Osmia coloradensis:  40%|███████▌           | 4/10 [00:00<00:00,  7.53it/s]
# Processing Osmia coloradensis:  50%|█████████▌         | 5/10 [00:00<00:00,  7.92it/s]
# Processing Osmia coloradensis:  60%|███████████▍       | 6/10 [00:00<00:00,  7.82it/s]
# Processing Osmia coloradensis:  70%|█████████████▎     | 7/10 [00:00<00:00,  7.71it/s]
# Processing Osmia coloradensis:  80%|███████████████▏   | 8/10 [00:01<00:00,  7.68it/s]
# Processing Osmia coloradensis:  90%|█████████████████  | 9/10 [00:01<00:00,  7.69it/s]
# Processing Osmia coloradensis: 100%|██████████████████| 10/10 [00:01<00:00,  7.80it/s]
# Processing folders:  90%|██████████████████████████▏  | 47/52 [00:43<00:03,  1.25it/s]
# Processing Osmia laeta:   0%|                                   | 0/7 [00:00<?, ?it/s]
# Processing Osmia laeta:  14%|███▊                       | 1/7 [00:00<00:00,  6.95it/s]
# Processing Osmia laeta:  29%|███████▋                   | 2/7 [00:00<00:00,  7.25it/s]
# Processing Osmia laeta:  43%|███████████▌               | 3/7 [00:00<00:00,  7.62it/s]
# Processing Osmia laeta:  57%|███████████████▍           | 4/7 [00:00<00:00,  7.72it/s]
# Processing Osmia laeta:  71%|███████████████████▎       | 5/7 [00:00<00:00,  7.78it/s]
# Processing Osmia laeta:  86%|███████████████████████▏   | 6/7 [00:00<00:00,  7.84it/s]
# Processing Osmia laeta: 100%|███████████████████████████| 7/7 [00:00<00:00,  7.91it/s]
# Processing folders:  92%|██████████████████████████▊  | 48/52 [00:44<00:03,  1.20it/s]
# Processing Osmia montana:   0%|                                 | 0/4 [00:00<?, ?it/s]
# Processing Osmia montana:  25%|██████▎                  | 1/4 [00:00<00:00,  6.68it/s]
# Processing Osmia montana:  50%|████████████▌            | 2/4 [00:00<00:00,  6.42it/s]
# Processing Osmia montana:  75%|██████████████████▊      | 3/4 [00:00<00:00,  6.94it/s]
# Processing Osmia montana: 100%|█████████████████████████| 4/4 [00:00<00:00,  7.17it/s]
# Processing folders:  94%|███████████████████████████▎ | 49/52 [00:44<00:02,  1.32it/s]
# Processing Osmia nemoris:   0%|                                | 0/22 [00:00<?, ?it/s]
# Processing Osmia nemoris:   5%|█                       | 1/22 [00:00<00:02,  7.49it/s]
# Processing Osmia nemoris:   9%|██▏                     | 2/22 [00:00<00:02,  7.94it/s]
# Processing Osmia nemoris:  14%|███▎                    | 3/22 [00:00<00:02,  7.76it/s]
# Processing Osmia nemoris:  18%|████▎                   | 4/22 [00:00<00:02,  7.16it/s]
# Processing Osmia nemoris:  23%|█████▍                  | 5/22 [00:00<00:02,  7.55it/s]
# Processing Osmia nemoris:  27%|██████▌                 | 6/22 [00:00<00:02,  7.54it/s]
# Processing Osmia nemoris:  32%|███████▋                | 7/22 [00:00<00:01,  7.55it/s]
# Processing Osmia nemoris:  36%|████████▋               | 8/22 [00:01<00:01,  7.28it/s]
# Processing Osmia nemoris:  41%|█████████▊              | 9/22 [00:01<00:01,  7.41it/s]
# Processing Osmia nemoris:  45%|██████████▍            | 10/22 [00:01<00:01,  7.43it/s]
# Processing Osmia nemoris:  50%|███████████▌           | 11/22 [00:01<00:01,  7.41it/s]
# Processing Osmia nemoris:  55%|████████████▌          | 12/22 [00:01<00:01,  7.00it/s]
# Processing Osmia nemoris:  59%|█████████████▌         | 13/22 [00:01<00:01,  7.17it/s]
# Processing Osmia nemoris:  64%|██████████████▋        | 14/22 [00:01<00:01,  7.26it/s]
# Processing Osmia nemoris:  68%|███████████████▋       | 15/22 [00:02<00:00,  7.21it/s]
# Processing Osmia nemoris:  73%|████████████████▋      | 16/22 [00:02<00:00,  7.36it/s]
# Processing Osmia nemoris:  77%|█████████████████▊     | 17/22 [00:02<00:00,  7.56it/s]
# Processing Osmia nemoris:  82%|██████████████████▊    | 18/22 [00:02<00:00,  7.58it/s]
# Processing Osmia nemoris:  86%|███████████████████▊   | 19/22 [00:02<00:00,  7.63it/s]
# Processing Osmia nemoris:  91%|████████████████████▉  | 20/22 [00:02<00:00,  7.21it/s]
# Processing Osmia nemoris:  95%|█████████████████████▉ | 21/22 [00:02<00:00,  7.21it/s]
# Processing Osmia nemoris: 100%|███████████████████████| 22/22 [00:02<00:00,  7.33it/s]
# Processing folders:  96%|███████████████████████████▉ | 50/52 [00:47<00:02,  1.43s/it]
# Processing Osmia tristella:   0%|                               | 0/4 [00:00<?, ?it/s]
# Processing Osmia tristella:  25%|█████▊                 | 1/4 [00:00<00:00,  8.01it/s]
# Processing Osmia tristella:  50%|███████████▌           | 2/4 [00:00<00:00,  7.73it/s]
# Processing Osmia tristella:  75%|█████████████████▎     | 3/4 [00:00<00:00,  7.18it/s]
# Processing Osmia tristella: 100%|███████████████████████| 4/4 [00:00<00:00,  7.17it/s]
# Processing folders:  98%|████████████████████████████▍| 51/52 [00:48<00:01,  1.16s/it]
# Processing Peponapis pruinosa:   0%|                           | 0/22 [00:00<?, ?it/s]
# Processing Peponapis pruinosa:   5%|▊                  | 1/22 [00:00<00:02,  7.78it/s]
# Processing Peponapis pruinosa:   9%|█▋                 | 2/22 [00:00<00:02,  7.72it/s]
# Processing Peponapis pruinosa:  14%|██▌                | 3/22 [00:00<00:02,  6.82it/s]
# Processing Peponapis pruinosa:  18%|███▍               | 4/22 [00:00<00:02,  6.92it/s]
# Processing Peponapis pruinosa:  23%|████▎              | 5/22 [00:00<00:02,  7.08it/s]
# Processing Peponapis pruinosa:  27%|█████▏             | 6/22 [00:00<00:02,  7.32it/s]
# Processing Peponapis pruinosa:  32%|██████             | 7/22 [00:00<00:02,  7.44it/s]
# Processing Peponapis pruinosa:  36%|██████▉            | 8/22 [00:01<00:01,  7.40it/s]
# Processing Peponapis pruinosa:  41%|███████▊           | 9/22 [00:01<00:01,  7.07it/s]
# Processing Peponapis pruinosa:  45%|████████▏         | 10/22 [00:01<00:01,  7.01it/s]
# Processing Peponapis pruinosa:  50%|█████████         | 11/22 [00:01<00:01,  6.48it/s]
# Processing Peponapis pruinosa:  55%|█████████▊        | 12/22 [00:01<00:01,  6.78it/s]
# Processing Peponapis pruinosa:  59%|██████████▋       | 13/22 [00:01<00:01,  6.95it/s]
# Processing Peponapis pruinosa:  64%|███████████▍      | 14/22 [00:01<00:01,  6.81it/s]
# Processing Peponapis pruinosa:  68%|████████████▎     | 15/22 [00:02<00:00,  7.03it/s]
# Processing Peponapis pruinosa:  73%|█████████████     | 16/22 [00:02<00:00,  7.19it/s]
# Processing Peponapis pruinosa:  77%|█████████████▉    | 17/22 [00:02<00:00,  7.38it/s]
# Processing Peponapis pruinosa:  82%|██████████████▋   | 18/22 [00:02<00:00,  6.91it/s]
# Processing Peponapis pruinosa:  86%|███████████████▌  | 19/22 [00:02<00:00,  6.97it/s]
# Processing Peponapis pruinosa:  91%|████████████████▎ | 20/22 [00:02<00:00,  7.19it/s]
# Processing Peponapis pruinosa:  95%|█████████████████▏| 21/22 [00:02<00:00,  7.39it/s]
# Processing Peponapis pruinosa: 100%|██████████████████| 22/22 [00:03<00:00,  7.58it/s]
# Processing folders: 100%|█████████████████████████████| 52/52 [00:51<00:00,  1.01it/s]
# Accuracy: 0.16216216216216217
